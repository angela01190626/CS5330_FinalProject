# %%
from tensorflow import keras
import tensorflow as tf
tf.config.run_functions_eagerly(True)

# %%
from keras.models import Sequential, Model

from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers import Conv2D, MaxPooling2D
from keras import layers

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import numpy as np
import pandas as pd
import cv2 
import os
import fnmatch
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
train_path = "Demo_dataset"
train_chinese = os.listdir(train_path)
df_train = pd.DataFrame(columns=["character", "filename", "label"])
df_test = pd.DataFrame(columns=["character", "filename", "label"])
len(train_chinese)
# Out:
# 7187

# %%
def image_preprocessing(df_train):
    array = np.zeros((df_train.shape[0], 128, 128, 3))
    for i in range(df_train.shape[0]):
        if df_train.iloc[i]['filename'] != ".DS_Store":
            image_path = train_path + '/' + df_train.iloc[i]['character'] + '/' + df_train.iloc[i]['filename']
            # get grayscale image
            # print(image_path)
            image = cv2.imread(image_path)
            # remove noise
            out = cv2.medianBlur(image, 5)
            # normalize the image
            resultimage = np.zeros(out.shape)
            normalizedimage = cv2.normalize(out, resultimage, 0, 255, cv2.NORM_MINMAX)
            # resize the image 
            resizeimage = cv2.resize(normalizedimage, (128,128))

            blue, green, red = cv2.split(resizeimage) 
            # apply principal component analysis
            pca = PCA(50)
            red_transformed = pca.fit_transform(red)
            red_inverted = pca.inverse_transform(red_transformed)

            #Applying to Green channel and then applying inverse transform to transformed array.
            green_transformed = pca.fit_transform(green)
            green_inverted = pca.inverse_transform(green_transformed)

            #Applying to Blue channel and then applying inverse transform to transformed array.
            blue_transformed = pca.fit_transform(blue)
            blue_inverted = pca.inverse_transform(blue_transformed)

            img_compressed = (np.dstack((red_inverted, red_inverted, red_inverted))).astype(np.uint8)
            array[i] = img_compressed
    return array

# %%
k = 0
for i in range(0, len(train_chinese)):
    if i != ".DS_Store":
        l = os.listdir(train_path + '/' + train_chinese[i])
        l = fnmatch.filter(l, '*.png')
        l = np.array(l)
        kf = KFold(n_splits = 5, random_state = None, shuffle = False)
        for j, (train_index, test_index) in enumerate(kf.split(l)):
            if len(l) >= 200:
                l = l[:200]
                label_train = [k] * len(l[train_index])
                label_test = [k] * len(l[test_index])
                temp1 = pd.DataFrame({
                    "character": train_chinese[i],
                    "filename": l[train_index],
                    "label": label_train
                })
                temp2 = pd.DataFrame({
                    "character": train_chinese[i],
                    "filename": l[test_index],
                    "label": label_test
                })
                #print(temp)
                df_train = pd.concat([df_train, temp1])  
                df_test = pd.concat([df_test, temp2])
        k += 1

# %%
train_array = image_preprocessing(df_train)
test_array = image_preprocessing(df_test)
#print(train_array.shape)
#print(test_array.shape)

X_train = train_array / 255.0
y_train = df_train["label"].to_numpy()
y_train = y_train.astype('int')


X_test = test_array / 255.0
y_test = df_test["label"].to_numpy()
y_test = y_test.astype('int')

# %%
train_X = np.zeros((5, X_train.shape[0] // 800 * 160, 128, 128, 3))
train_y = np.zeros((5, y_train.shape[0] // 800 * 160))
test_X = np.zeros((5, X_test.shape[0] // 200 * 40, 128, 128, 3))
test_y = np.zeros((5, y_test.shape[0] // 200 * 40))

# %%
for i in range(8):
    x1 = X_train[800 * i : 800 * (i + 1)]
    y1 = y_train[800 * i : 800 * (i + 1)]
    x2 = X_test[200 * i : 200  * (i + 1)]
    y2 = y_test[200 * i : 200 * (i + 1)]
    for j in range(5):
        #print(i, j)
        #print(160 * i, 160 * (i+1))
        train_X[j][160 * i  : 160 * (i+1)]  = x1[160 * j : 160 * (j + 1)]
        train_y[j][160 * i  : 160 * (i+1)]  = y1[160 * j : 160 * (j + 1)]
        test_X[j][40 * i : 40 * (i + 1)] = x2[40 * j : 40  * (j + 1)]
        test_y[j][40 * i : 40 * (i + 1)] = y2[40 * j : 40  * (j + 1)]

# %%
models = []
for i in range(5):
    model = keras.models.Sequential([

        keras.layers.Conv2D(filters=64, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(128,128,3)),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPool2D(pool_size=(2,2)),
        keras.layers.Conv2D(filters=128, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPool2D(pool_size=(3,3)),
        keras.layers.Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
        keras.layers.BatchNormalization(),
        keras.layers.Conv2D(filters=128, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPool2D(pool_size=(2,2)),
        keras.layers.Flatten(),

        keras.layers.Dense(1024,activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(1024,activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(8,activation='softmax')  

    ])
    models.append(model)

# %%
accuracy = []
for i in range(5):
    models[i].compile(
        loss='sparse_categorical_crossentropy',
        optimizer=tf.optimizers.SGD(learning_rate=0.001),
        metrics=['accuracy']    
    )
    history=models[i].fit(
        train_X[i], train_y[i],
        epochs = 20,
        validation_data = (test_X[i], test_y[i]),
        validation_freq = 1
    )
    accuracy.append(np.max(history.history['val_accuracy']))
# Out:
# Epoch 1/20
# 40/40 [==============================] - 15s 384ms/step - loss: 2.5656 - accuracy: 0.1930 - val_loss: 2.0767 - val_accuracy: 0.1250
# Epoch 2/20
# 40/40 [==============================] - 15s 365ms/step - loss: 2.0236 - accuracy: 0.2750 - val_loss: 2.0903 - val_accuracy: 0.1250
# Epoch 3/20
# 40/40 [==============================] - 13s 321ms/step - loss: 1.7076 - accuracy: 0.3820 - val_loss: 2.0995 - val_accuracy: 0.1656
# Epoch 4/20
# 40/40 [==============================] - 13s 319ms/step - loss: 1.5009 - accuracy: 0.4578 - val_loss: 2.0858 - val_accuracy: 0.2406
# Epoch 5/20
# 40/40 [==============================] - 13s 314ms/step - loss: 1.3335 - accuracy: 0.5188 - val_loss: 2.0344 - val_accuracy: 0.2531
# Epoch 6/20
# 40/40 [==============================] - 13s 331ms/step - loss: 1.1212 - accuracy: 0.6023 - val_loss: 1.8999 - val_accuracy: 0.3125
# Epoch 7/20
# 40/40 [==============================] - 13s 319ms/step - loss: 1.0257 - accuracy: 0.6242 - val_loss: 1.6918 - val_accuracy: 0.4094
# 40/40 [==============================] - 12s 306ms/step - loss: 1.1811 - accuracy: 0.5703 - val_loss: 1.7749 - val_accuracy: 0.2906
# Epoch 7/20
# 40/40 [==============================] - 15s 368ms/step - loss: 1.0863 - accuracy: 0.6133 - val_loss: 1.4358 - val_accuracy: 0.6094
# Epoch 8/20
# 40/40 [==============================] - 15s 371ms/step - loss: 0.9032 - accuracy: 0.6797 - val_loss: 1.1868 - val_accuracy: 0.6344
# Epoch 9/20
# 40/40 [==============================] - 13s 318ms/step - loss: 0.8712 - accuracy: 0.6969 - val_loss: 1.0098 - val_accuracy: 0.7750
# Epoch 10/20
# 40/40 [==============================] - 15s 377ms/step - loss: 0.7457 - accuracy: 0.7484 - val_loss: 0.6504 - val_accuracy: 0.9156
# Epoch 11/20
# 40/40 [==============================] - 13s 313ms/step - loss: 0.6690 - accuracy: 0.7648 - val_loss: 0.5998 - val_accuracy: 0.8906
# Epoch 12/20
# 40/40 [==============================] - 14s 349ms/step - loss: 0.6430 - accuracy: 0.7852 - val_loss: 0.4465 - val_accuracy: 0.9219
# Epoch 13/20
# 40/40 [==============================] - 13s 316ms/step - loss: 0.5690 - accuracy: 0.8055 - val_loss: 0.4120 - val_accuracy: 0.9094
# Epoch 14/20
# 40/40 [==============================] - 13s 324ms/step - loss: 0.5147 - accuracy: 0.8281 - val_loss: 0.3299 - val_accuracy: 0.9344
# Epoch 15/20
# 40/40 [==============================] - 15s 369ms/step - loss: 0.4925 - accuracy: 0.8414 - val_loss: 0.4021 - val_accuracy: 0.8875
# Epoch 16/20
# 40/40 [==============================] - 16s 389ms/step - loss: 0.4177 - accuracy: 0.8594 - val_loss: 0.2622 - val_accuracy: 0.9469
# Epoch 17/20
# 40/40 [==============================] - 15s 365ms/step - loss: 0.3860 - accuracy: 0.8758 - val_loss: 0.2590 - val_accuracy: 0.9312
# Epoch 18/20
# 40/40 [==============================] - 13s 319ms/step - loss: 0.3519 - accuracy: 0.8898 - val_loss: 0.2703 - val_accuracy: 0.9406
# Epoch 19/20
# 40/40 [==============================] - 13s 320ms/step - loss: 0.3438 - accuracy: 0.8953 - val_loss: 0.2171 - val_accuracy: 0.9500
# Epoch 20/20
# 40/40 [==============================] - 13s 335ms/step - loss: 0.3117 - accuracy: 0.9141 - val_loss: 0.2030 - val_accuracy: 0.9563
# Epoch 1/20
# 40/40 [==============================] - 14s 345ms/step - loss: 2.6006 - accuracy: 0.1789 - val_loss: 2.0755 - val_accuracy: 0.1312
# Epoch 2/20
# 40/40 [==============================] - 15s 386ms/step - loss: 2.0734 - accuracy: 0.2852 - val_loss: 2.0789 - val_accuracy: 0.1187
# Epoch 3/20
# 40/40 [==============================] - 15s 386ms/step - loss: 1.6645 - accuracy: 0.3977 - val_loss: 2.0862 - val_accuracy: 0.1250
# Epoch 4/20
# 40/40 [==============================] - 14s 349ms/step - loss: 1.4552 - accuracy: 0.4547 - val_loss: 2.0646 - val_accuracy: 0.1406
# Epoch 5/20
# Epoch 4/20
# 40/40 [==============================] - 13s 316ms/step - loss: 1.6386 - accuracy: 0.4070 - val_loss: 2.0924 - val_accuracy: 0.1312
# Epoch 5/20
# 40/40 [==============================] - 13s 322ms/step - loss: 1.4276 - accuracy: 0.4742 - val_loss: 2.0340 - val_accuracy: 0.1719
# Epoch 6/20
# 40/40 [==============================] - 13s 314ms/step - loss: 1.2328 - accuracy: 0.5430 - val_loss: 1.9192 - val_accuracy: 0.2656
# Epoch 7/20
# 40/40 [==============================] - 13s 325ms/step - loss: 1.0748 - accuracy: 0.6242 - val_loss: 1.6576 - val_accuracy: 0.4344
# Epoch 8/20
# 40/40 [==============================] - 13s 320ms/step - loss: 0.9653 - accuracy: 0.6602 - val_loss: 1.2918 - val_accuracy: 0.6656
# Epoch 9/20
# 40/40 [==============================] - 13s 325ms/step - loss: 0.8498 - accuracy: 0.7063 - val_loss: 1.2510 - val_accuracy: 0.5625
# Epoch 10/20
# 40/40 [==============================] - 13s 324ms/step - loss: 0.8061 - accuracy: 0.7180 - val_loss: 0.7948 - val_accuracy: 0.8000
# Epoch 11/20
# 40/40 [==============================] - 13s 330ms/step - loss: 0.7056 - accuracy: 0.7648 - val_loss: 0.5774 - val_accuracy: 0.8844
# Epoch 12/20
# 40/40 [==============================] - 13s 330ms/step - loss: 0.6223 - accuracy: 0.8062 - val_loss: 0.4922 - val_accuracy: 0.8906
# Epoch 13/20
# 40/40 [==============================] - 18s 465ms/step - loss: 0.5619 - accuracy: 0.8289 - val_loss: 0.5034 - val_accuracy: 0.8813
# Epoch 14/20
# 40/40 [==============================] - 15s 375ms/step - loss: 0.5355 - accuracy: 0.8211 - val_loss: 0.3779 - val_accuracy: 0.9031
# Epoch 15/20
# 40/40 [==============================] - 13s 319ms/step - loss: 0.4745 - accuracy: 0.8461 - val_loss: 0.3369 - val_accuracy: 0.9187
# Epoch 16/20
# 40/40 [==============================] - 13s 326ms/step - loss: 0.4259 - accuracy: 0.8625 - val_loss: 0.4093 - val_accuracy: 0.8938
# Epoch 17/20
# 40/40 [==============================] - 14s 340ms/step - loss: 0.4189 - accuracy: 0.8797 - val_loss: 0.2868 - val_accuracy: 0.9312
# Epoch 18/20
# 40/40 [==============================] - 13s 327ms/step - loss: 0.3880 - accuracy: 0.8859 - val_loss: 0.2614 - val_accuracy: 0.9250
# Epoch 19/20
# 40/40 [==============================] - 24s 604ms/step - loss: 0.3590 - accuracy: 0.8922 - val_loss: 0.2914 - val_accuracy: 0.9375
# Epoch 20/20
# 40/40 [==============================] - 16s 400ms/step - loss: 0.3451 - accuracy: 0.8945 - val_loss: 0.2923 - val_accuracy: 0.9062
# Epoch 1/20
# 40/40 [==============================] - 14s 356ms/step - loss: 2.5428 - accuracy: 0.1977 - val_loss: 2.0752 - val_accuracy: 0.2313
# Epoch 2/20
# 40/40 [==============================] - 15s 364ms/step - loss: 2.0001 - accuracy: 0.3094 - val_loss: 2.0752 - val_accuracy: 0.1688
# Epoch 3/20
# 40/40 [==============================] - 13s 326ms/step - loss: 1.7410 - accuracy: 0.3805 - val_loss: 2.0652 - val_accuracy: 0.1656
# Epoch 4/20
# 40/40 [==============================] - 13s 325ms/step - loss: 1.4688 - accuracy: 0.4578 - val_loss: 2.0336 - val_accuracy: 0.1688
# Epoch 5/20
# 40/40 [==============================] - 14s 342ms/step - loss: 1.2614 - accuracy: 0.5336 - val_loss: 1.9396 - val_accuracy: 0.2031
# Epoch 6/20
# 40/40 [==============================] - 13s 322ms/step - loss: 1.1597 - accuracy: 0.5820 - val_loss: 1.7552 - val_accuracy: 0.3656
# Epoch 7/20
# 40/40 [==============================] - 13s 326ms/step - loss: 1.0017 - accuracy: 0.6367 - val_loss: 1.5871 - val_accuracy: 0.4406
# Epoch 8/20
# 40/40 [==============================] - 13s 326ms/step - loss: 0.8928 - accuracy: 0.6805 - val_loss: 1.1667 - val_accuracy: 0.7281
# Epoch 9/20
# 40/40 [==============================] - 13s 320ms/step - loss: 0.8060 - accuracy: 0.7258 - val_loss: 0.9264 - val_accuracy: 0.8281
# Epoch 10/20
# 40/40 [==============================] - 13s 326ms/step - loss: 0.7453 - accuracy: 0.7531 - val_loss: 0.8285 - val_accuracy: 0.7375
# Epoch 11/20
# 40/40 [==============================] - 13s 321ms/step - loss: 0.6427 - accuracy: 0.8086 - val_loss: 0.7499 - val_accuracy: 0.7312
# Epoch 12/20
# 40/40 [==============================] - 13s 334ms/step - loss: 0.5785 - accuracy: 0.8203 - val_loss: 0.5205 - val_accuracy: 0.8906
# Epoch 13/20
# 40/40 [==============================] - 13s 325ms/step - loss: 0.5452 - accuracy: 0.8172 - val_loss: 0.4336 - val_accuracy: 0.8813
# Epoch 14/20
# 40/40 [==============================] - 13s 324ms/step - loss: 0.4920 - accuracy: 0.8320 - val_loss: 0.3897 - val_accuracy: 0.8844
# Epoch 15/20
# 40/40 [==============================] - 13s 322ms/step - loss: 0.4516 - accuracy: 0.8594 - val_loss: 0.3804 - val_accuracy: 0.9000
# Epoch 16/20
# 40/40 [==============================] - 15s 378ms/step - loss: 0.3898 - accuracy: 0.8891 - val_loss: 0.3619 - val_accuracy: 0.8844
# Epoch 17/20
# 40/40 [==============================] - 13s 325ms/step - loss: 0.3656 - accuracy: 0.8898 - val_loss: 0.3006 - val_accuracy: 0.9156
# Epoch 18/20
# 40/40 [==============================] - 13s 324ms/step - loss: 0.3608 - accuracy: 0.8836 - val_loss: 0.2766 - val_accuracy: 0.9219
# Epoch 19/20
# 40/40 [==============================] - 13s 329ms/step - loss: 0.3204 - accuracy: 0.9125 - val_loss: 0.2498 - val_accuracy: 0.9219
# Epoch 20/20
# 40/40 [==============================] - 13s 329ms/step - loss: 0.2824 - accuracy: 0.9156 - val_loss: 0.2461 - val_accuracy: 0.9281

# %%
mean_accuracy = np.mean(accuracy)
mean_accuracy
# Out:
# 0.9325000047683716
